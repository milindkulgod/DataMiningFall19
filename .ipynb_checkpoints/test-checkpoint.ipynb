# %%
  
import numpy as np
import pandas as pd
import pickle
import string 
import html
import ast
import re
import nltk
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.corpus import wordnet
stpwrds = stopwords.words("english")
from nltk.stem import WordNetLemmatizer

def encode_reviews(review):
    return html.unescape(review)

def rm_stopword(r):
    r_n = " ".join([i for i in r if i not in stpwrds])
    return r_n
    
def lem(tokens):
    l = WordNetLemmatizer()
    out = [l.lemmatize(word) for word in tokens]
    return out
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\makul\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
 data = pd.read_csv('rawdata.csv')

# %%
data['review'] = data['review'].apply(encode_reviews)

# %%
data['review']
# Out:
# 0        "I've tried a few antidepressants over the yea...
# 1        "My son has Crohn's disease and has done very ...
# 2                            "Quick reduction of symptoms"
# 3        "Contrave combines drugs that were used for al...
# 4        "I have been on this birth control for one cyc...
# 5        "4 days in on first 2 weeks.  Using on arms an...
# 6        "I've had the copper coil for about 3 months n...
# 7        "This has been great for me. I've been on it f...
# 8        "Ive been on Methadone for over ten years and ...
# 9        "I was on this pill for almost two years. It d...
# 10       "Holy Hell is exactly how I feel. I had been t...
# 11       "Honestly its day one on the 3 day treatment. ...
# 12       "This is a waste of money.  Did not curb my ap...
# 13                      "No problems, watch what you eat."
# 14       "Ditto on rebound sleepless when discontinued....
# 15       "A doctor in the ER prescribed me 200 mg of Pr...
# 16       "I smoked for 50+ years.  Took it for one week...
# 17       "So I was on Ginanvi for about 3 months before...
# 18       "This medication helped me  sleep, but eventua...
# 19       "After just 1 dose of this ciprofloxacn, I fel...
# 20       "If I could give it a 0, I would absolutely do...
# 21       "I am so happy with the samples provided by my...
# 22       "After a few days and it "kicked in," every no...
# 23                  "They didn't help my dry eyes at all."
# 24       "This drug is pretty amazing. I've had hyperhy...
# 25       "This medication should not be being prescribe...
# 26        "klonopin has definitely given me my life back!"
# 27       "Worked quickly and well. I learned by trial t...
# 28       "2.75g x 2 every night for five years. Deeper ...
# 29       "I am a 25 year old female. I was diagnosed wi...
#                                ...
# 53736    "Ativan works. I just started getting panic at...
# 53737    "Major sleepiness. Used it in the morning and ...
# 53738    "Took antibiotics and got a yeast infection we...
# 53739    "Ambien is a wonderful sleep aid.  For people ...
# 53740    "I had mild Barrett's esophagus and was on Dex...
# 53741    "I first would like to thank all of you that p...
# 53742    "Have been taking it for 6 years (120 milligra...
# 53743    "Clarifoam EF is a wonderful product.  I have ...
# 53744    "Woman of Cuban and Puerto Rican heritage 5'1 ...
# 53745    "I've been on clomipramine 15 years now and ba...
# 53746    "I've had diarrhoea for 3 days now with minima...
# 53747    "Horrible! I have been a smoker for 14 years. ...
# 53748                   "Glad to have it available to me."
# 53749    "After 16 years of opioid and heroin addiction...
# 53750    "I have had the worst experience with this pil...
# 53751    "I took chantix a little over a month. It made...
# 53752    "After first month of taking Epclusa, I am und...
# 53753    "Diagnosed with general anxiety disorder.  Wou...
# 53754    "It didn't help me at all. I craved chocolate ...
# 53755    "I now suffer from excessive tiredness and lac...
# 53756    "Treatment for ADHD save my life. Don't believ...
# 53757    "This is my 3rd time taking this medicine. Fir...
# 53758    "This medicine kept me from sleeping the whole...
# 53759    "I was on Microgestin for about 3 years. Over ...
# 53760    "I started taking Apri about 7 months ago. My ...
# 53761    "I have taken Tamoxifen for 5 years. Side effe...
# 53762    "I've been taking Lexapro (escitaploprgram) si...
# 53763    "I'm married, 34 years old and I have no kids....
# 53764    "I was prescribed Nucynta for severe neck/shou...
# 53765                                        "It works!!!"
# Name: review, Length: 53766, dtype: object

# %%
reviews = data['review'].str.replace("[^a-zA-Z]", " ")

# %%
reviews = reviews.apply(lambda r: " ".join([w for w in r.split() if len(w)>2]))

# %%
reviews
# Out:
# 0        tried few antidepressants over the years cital...
# 1        son has Crohn disease and has done very well t...
# 2                                 Quick reduction symptoms
# 3        Contrave combines drugs that were used for alc...
# 4        have been this birth control for one cycle Aft...
# 5        days first weeks Using arms and face Put vasel...
# 6        had the copper coil for about months now was r...
# 7        This has been great for been for weeks and the...
# 8        Ive been Methadone for over ten years and curr...
# 9        was this pill for almost two years does work f...
# 10       Holy Hell exactly how feel had been taking Bri...
# 11       Honestly its day one the day treatment Yes bur...
# 12       This waste money Did not curb appetite nor did...
# 13                             problems watch what you eat
# 14       Ditto rebound sleepless when discontinued have...
# 15       doctor the prescribed Provigil when was first ...
# 16       smoked for years Took for one week and that wa...
# 17       was Ginanvi for about months before switched o...
# 18       This medication helped sleep but eventually be...
# 19           After just dose this ciprofloxacn felt better
# 20       could give would absolutely Started and felt W...
# 21       happy with the samples provided Endocrinologis...
# 22       After few days and kicked every noise the hous...
# 23                             They didn help dry eyes all
# 24       This drug pretty amazing had hyperhydrosis the...
# 25       This medication should not being prescribed fo...
# 26                 klonopin has definitely given life back
# 27       Worked quickly and well learned trial that tri...
# 28       every night for five years Deeper sleep with d...
# 29       year old female was diagnosed with bipolar dis...
#                                ...
# 53736    Ativan works just started getting panic attack...
# 53737    Major sleepiness Used the morning and the even...
# 53738    Took antibiotics and got yeast infection went ...
# 53739    Ambien wonderful sleep aid For people who have...
# 53740    had mild Barrett esophagus and was Dexilant fo...
# 53741    first would like thank all you that posted com...
# 53742    Have been taking for years milligrams side eff...
# 53743    Clarifoam wonderful product have Rosacea and s...
# 53744    Woman Cuban and Puerto Rican heritage and poun...
# 53745    been clomipramine years now and basically save...
# 53746    had diarrhoea for days now with minimal sleep ...
# 53747    Horrible have been smoker for years tried chan...
# 53748                                  Glad have available
# 53749    After years opioid and heroin addiction had tr...
# 53750    have had the worst experience with this pill T...
# 53751    took chantix little over month made have psych...
# 53752        After first month taking Epclusa undetectable
# 53753    Diagnosed with general anxiety disorder Would ...
# 53754    didn help all craved chocolate all the time No...
# 53755    now suffer from excessive tiredness and lack e...
# 53756    Treatment for ADHD save life Don believe all t...
# 53757    This time taking this medicine First times shi...
# 53758    This medicine kept from sleeping the whole day...
# 53759    was Microgestin for about years Over the past ...
# 53760    started taking Apri about months ago breats go...
# 53761    have taken Tamoxifen for years Side effects ar...
#  'have sinus infection months tried types antibiotics would help little right back stuff major congestion hard phlegm trouble breathing etc took azithromycin day able breathe thru nose loosened mucus day felt like new person',
#  'using pentasa times day total pills definitely helps sometimes get headaches feel sick sometimes occasionally get pain reason ever since started taking get weird skin patches',
#  'cannot believe amazing medicine cystic acne tried monocycline doxycycline prescription topical creams nothing worked finally decided ask doctor bactrim completely cyst free since october this record amount time cysts maybe three pimples side effects the monocycline gave horrible joint aches point almost cry hurt bad far absolutely side effects wonderful',
#  'doctor put loestrin endometriosis worked heavy bleeding pain also gained weight pounds mths using mind underweight begin light periods also noticed change mood terrible pms mood swings depression gone stable mood month long however soon started taking face broke cystic acne worst ever getting worse every day keep taking drug face covered dark marks painful volcano like zits also oily also grew two spiky long chin hairs',
#  ...]

# %%
reviews = pd.Series(reviews)

# %%
reviews
# Out:
# 0        tried antidepressants years citalopram fluoxet...
# 1        son crohn disease done well asacol complaints ...
# 2                                 quick reduction symptoms
# 3        contrave combines drugs used alcohol smoking o...
# 4        birth control one cycle after reading reviews ...
# 5        days first weeks using arms face put vaseline ...
# 6        copper coil months really excited thought taki...
# 7        this great weeks last week headaches went away...
# 8        ive methadone ten years currently trying get d...
# 9        pill almost two years work far getting pregnan...
# 10       holy hell exactly feel taking brisdelle years ...
# 11       honestly day one day treatment yes burns bit l...
# 12       this waste money did curb appetite make feel full
# 13                                      problems watch eat
# 14       ditto rebound sleepless discontinued done stra...
# 15       doctor prescribed provigil first diagnosed nar...
# 16       smoked years took one week think possible quit...
# 17       ginanvi months switched pill due high cost gin...
# 18       this medication helped sleep eventually became...
# 19                     after dose ciprofloxacn felt better
# 20       could give would absolutely started felt wired...
# 21       happy samples provided endocrinologist the thi...
# 22       after days kicked every noise house would make...
# 23                                      they help dry eyes
# 24       this drug pretty amazing hyperhydrosis palms s...
# 25       this medication prescribed bipolar milder form...
# 26                     klonopin definitely given life back
# 27       worked quickly well learned trial trimming fil...
# 28       every night five years deeper sleep dreaming i...
# 29       year old female diagnosed bipolar disorder yea...
#                                ...
# 53736    ativan works started getting panic attacks rea...
# 53737    major sleepiness used morning evening tired da...
# 53738    took antibiotics got yeast infection went drs ...
# 53739    ambien wonderful sleep aid for people trouble ...
# 53740    mild barrett esophagus dexilant month due loss...
# 53741    first would like thank posted comments after r...
# 53742            have taking years milligrams side effects
# 53743    clarifoam wonderful product rosacea seb derm t...
# 53744    woman cuban puerto rican heritage pounds wish ...
# 53745    clomipramine years basically saved life suffer...
# 53746    diarrhoea days minimal sleep constant abdomina...
# 53747    horrible smoker years tried chantix dreams bad...
# 53748                                       glad available
# 53749    after years opioid heroin addiction tried ever...
# 53750    worst experience pill took one pill head start...
# 53751    took chantix little month made psychotic split...
# 53752        after first month taking epclusa undetectable
# 53753    diagnosed general anxiety disorder would obses...
# 53754           help craved chocolate time not worth month
# 53755    suffer excessive tiredness lack energy consult...
# 53756    treatment adhd save life don believe hype stig...
# 53757    this time taking medicine first times shin bon...
# 53758    this medicine kept sleeping whole days body st...
# 53759    microgestin years over past year started get e...
# 53760    started taking apri months ago breats got noti...
# 53761    taken tamoxifen years side effects severe swea...
# 53762    taking lexapro escitaploprgram since february ...
# 53763    married years old kids taking pill hassle deci...
# 53764    prescribed nucynta severe neck shoulder pain a...
# 53765                                                works
# Length: 53766, dtype: object

# %%
tokenized = reviews.apply(lambda r: r.split())

# %%
tokenized
# Out:
# 0        [tried, antidepressants, years, citalopram, fl...
# 1        [son, crohn, disease, done, well, asacol, comp...
# 2                             [quick, reduction, symptoms]
# 3        [contrave, combines, drugs, used, alcohol, smo...
# 4        [birth, control, one, cycle, after, reading, r...
# 5        [days, first, weeks, using, arms, face, put, v...
# 6        [copper, coil, months, really, excited, though...
# 7        [this, great, weeks, last, week, headaches, we...
# 8        [ive, methadone, ten, years, currently, trying...
# 9        [pill, almost, two, years, work, far, getting,...
# 10       [holy, hell, exactly, feel, taking, brisdelle,...
# 11       [honestly, day, one, day, treatment, yes, burn...
# 12       [this, waste, money, did, curb, appetite, make...
# 13                                  [problems, watch, eat]
# 14       [ditto, rebound, sleepless, discontinued, done...
# 15       [doctor, prescribed, provigil, first, diagnose...
# 16       [smoked, years, took, one, week, think, possib...
# 17       [ginanvi, months, switched, pill, due, high, c...
# 18       [this, medication, helped, sleep, eventually, ...
# 19               [after, dose, ciprofloxacn, felt, better]
# 20       [could, give, would, absolutely, started, felt...
# 21       [happy, samples, provided, endocrinologist, th...
# 22       [after, days, kicked, every, noise, house, wou...
# 23                                 [they, help, dry, eyes]
# 24       [this, drug, pretty, amazing, hyperhydrosis, p...
# 25       [this, medication, prescribed, bipolar, milder...
# 26               [klonopin, definitely, given, life, back]
# 27       [worked, quickly, well, learned, trial, trimmi...
# 28       [every, night, five, years, deeper, sleep, dre...
# 29       [year, old, female, diagnosed, bipolar, disord...
#                                ...
# 53736    [ativan, works, started, getting, panic, attac...
# 53737    [major, sleepiness, used, morning, evening, ti...
# 53738    [took, antibiotics, got, yeast, infection, wen...
# 53739    [ambien, wonderful, sleep, aid, for, people, t...
# 53740    [mild, barrett, esophagus, dexilant, month, du...
# 53741    [first, would, like, thank, posted, comments, ...
# 53742     [have, taking, years, milligrams, side, effects]
# 53743    [clarifoam, wonderful, product, rosacea, seb, ...
# 53744    [woman, cuban, puerto, rican, heritage, pounds...
# 53745    [clomipramine, years, basically, saved, life, ...
# 53746    [diarrhoea, days, minimal, sleep, constant, ab...
# 53747    [horrible, smoker, years, tried, chantix, drea...
# 53748                                    [glad, available]
# 53749    [after, years, opioid, heroin, addiction, trie...
# 53750    [worst, experience, pill, took, one, pill, hea...
# 53751    [took, chantix, little, month, made, psychotic...
# 53752    [after, first, month, taking, epclusa, undetec...
# 53753    [diagnosed, general, anxiety, disorder, would,...
# 53754    [help, craved, chocolate, time, not, worth, mo...
# 53755    [suffer, excessive, tiredness, lack, energy, c...
# 53756    [treatment, adhd, save, life, don, believe, hy...
# 53757    [this, time, taking, medicine, first, times, s...
# 53758    [this, medicine, kept, sleeping, whole, days, ...
# 53759    [microgestin, years, over, past, year, started...
# 53760    [started, taking, apri, months, ago, breats, g...
# 53761    [taken, tamoxifen, years, side, effects, sever...
# 53762    [taking, lexapro, escitaploprgram, since, febr...
# 53763    [married, years, old, kids, taking, pill, hass...
# 53764    [prescribed, nucynta, severe, neck, shoulder, ...
# 53765                                              [works]
# Length: 53766, dtype: object

# %%
reviews
# Out:
# 0        tried antidepressants years citalopram fluoxet...
# 1        son crohn disease done well asacol complaints ...
# 2                                 quick reduction symptoms
# 3        contrave combines drugs used alcohol smoking o...
# 4        birth control one cycle after reading reviews ...
# 5        days first weeks using arms face put vaseline ...
# 6        copper coil months really excited thought taki...
# 7        this great weeks last week headaches went away...
# 8        ive methadone ten years currently trying get d...
# 9        pill almost two years work far getting pregnan...
# 10       holy hell exactly feel taking brisdelle years ...
# 11       honestly day one day treatment yes burns bit l...
# 12       this waste money did curb appetite make feel full
# 13                                      problems watch eat
# 14       ditto rebound sleepless discontinued done stra...
# 15       doctor prescribed provigil first diagnosed nar...
# 16       smoked years took one week think possible quit...
# 17       ginanvi months switched pill due high cost gin...
# 18       this medication helped sleep eventually became...
# 19                     after dose ciprofloxacn felt better
# 20       could give would absolutely started felt wired...
# 21       happy samples provided endocrinologist the thi...
# 22       after days kicked every noise house would make...
# 23                                      they help dry eyes
# 24       this drug pretty amazing hyperhydrosis palms s...
# 25       this medication prescribed bipolar milder form...
# 26                     klonopin definitely given life back
# 27       worked quickly well learned trial trimming fil...
# 28       every night five years deeper sleep dreaming i...
# 29       year old female diagnosed bipolar disorder yea...
#                                ...
# 53736    ativan works started getting panic attacks rea...
# 53737    major sleepiness used morning evening tired da...
# 53738    took antibiotics got yeast infection went drs ...
# 53739    ambien wonderful sleep aid for people trouble ...
# 53740    mild barrett esophagus dexilant month due loss...
# 53741    first would like thank posted comments after r...
# 53742            have taking years milligrams side effects
# 53743    clarifoam wonderful product rosacea seb derm t...
# 53744    woman cuban puerto rican heritage pounds wish ...
# 53745    clomipramine years basically saved life suffer...
# 53746    diarrhoea days minimal sleep constant abdomina...
# 53747    horrible smoker years tried chantix dreams bad...
# 53748                                       glad available
# 53749    after years opioid heroin addiction tried ever...
# 53750    worst experience pill took one pill head start...
# 53751    took chantix little month made psychotic split...
# 53752        after first month taking epclusa undetectable
# 53753    diagnosed general anxiety disorder would obses...
# 53754           help craved chocolate time not worth month
# 53755    suffer excessive tiredness lack energy consult...
# 53756    treatment adhd save life don believe hype stig...
# 53757    this time taking medicine first times shin bon...
# 53758    this medicine kept sleeping whole days body st...
# 53759    microgestin years over past year started get e...
# 53760    started taking apri months ago breats got noti...
# 53761    taken tamoxifen years side effects severe swea...
# 53762    taking lexapro escitaploprgram since february ...
# 53763    married years old kids taking pill hassle deci...
# 53764    prescribed nucynta severe neck shoulder pain a...
# 53765                                                works
# Length: 53766, dtype: object

# %%
tokenized
# Out:
# 0        [tried, antidepressants, years, citalopram, fl...
# 1        [son, crohn, disease, done, well, asacol, comp...
# 2                             [quick, reduction, symptoms]
# 3        [contrave, combines, drugs, used, alcohol, smo...
# 4        [birth, control, one, cycle, after, reading, r...
# 5        [days, first, weeks, using, arms, face, put, v...
# 6        [copper, coil, months, really, excited, though...
# 7        [this, great, weeks, last, week, headaches, we...
# 8        [ive, methadone, ten, years, currently, trying...
# 9        [pill, almost, two, years, work, far, getting,...
# 10       [holy, hell, exactly, feel, taking, brisdelle,...
# 11       [honestly, day, one, day, treatment, yes, burn...
# 12       [this, waste, money, did, curb, appetite, make...
# 13                                  [problems, watch, eat]
# 14       [ditto, rebound, sleepless, discontinued, done...
# 15       [doctor, prescribed, provigil, first, diagnose...
# 16       [smoked, years, took, one, week, think, possib...
# 17       [ginanvi, months, switched, pill, due, high, c...
# 18       [this, medication, helped, sleep, eventually, ...
# 19               [after, dose, ciprofloxacn, felt, better]
# 20       [could, give, would, absolutely, started, felt...
# 21       [happy, samples, provided, endocrinologist, th...
# 22       [after, days, kicked, every, noise, house, wou...
# 23                                 [they, help, dry, eyes]
# 24       [this, drug, pretty, amazing, hyperhydrosis, p...
# 25       [this, medication, prescribed, bipolar, milder...
# 26               [klonopin, definitely, given, life, back]
# 27       [worked, quickly, well, learned, trial, trimmi...
# 28       [every, night, five, years, deeper, sleep, dre...
# 29       [year, old, female, diagnosed, bipolar, disord...
#                                ...
# 53736    [ativan, works, started, getting, panic, attac...
# 53737    [major, sleepiness, used, morning, evening, ti...
# 53738    [took, antibiotics, got, yeast, infection, wen...
# 53739    [ambien, wonderful, sleep, aid, for, people, t...
# 53740    [mild, barrett, esophagus, dexilant, month, du...
# 53741    [first, would, like, thank, posted, comments, ...
# 53742     [have, taking, years, milligrams, side, effects]
# 53743    [clarifoam, wonderful, product, rosacea, seb, ...
# 53744    [woman, cuban, puerto, rican, heritage, pounds...
# 53745    [clomipramine, years, basically, saved, life, ...
# 53746    [diarrhoea, days, minimal, sleep, constant, ab...
# 53747    [horrible, smoker, years, tried, chantix, drea...
# 53748                                    [glad, available]
# 53749    [after, years, opioid, heroin, addiction, trie...
# 53750    [worst, experience, pill, took, one, pill, hea...
# 53751    [took, chantix, little, month, made, psychotic...
# 53752    [after, first, month, taking, epclusa, undetec...
# 53753    [diagnosed, general, anxiety, disorder, would,...
# 53754    [help, craved, chocolate, time, not, worth, mo...
# 53755    [suffer, excessive, tiredness, lack, energy, c...
# 53756    [treatment, adhd, save, life, don, believe, hy...
# 53757    [this, time, taking, medicine, first, times, s...
# 53758    [this, medicine, kept, sleeping, whole, days, ...
# 53759    [microgestin, years, over, past, year, started...
# 53760    [started, taking, apri, months, ago, breats, g...
# 53761    [taken, tamoxifen, years, side, effects, sever...
# 53762    [taking, lexapro, escitaploprgram, since, febr...
# 53763    [married, years, old, kids, taking, pill, hass...
# 53764    [prescribed, nucynta, severe, neck, shoulder, ...
# 53765                                              [works]
# Length: 53766, dtype: object

# %%
reviews = tokenized.apply(lem)

# %%
reviews[24]
# Out:
# ['this',
#  'drug',
#  'pretty',
#  'amazing',
#  'hyperhydrosis',
#  'palm',
#  'sol',
#  'underarms',
#  'since',
#  'hitting',
#  'puberty',
#  'skeptic',
#  'since',
#  'previously',
#  'tried',
#  'botox',
#  'iontophoresis',
#  'drysol',
#  'limited',
#  'result',
#  'however',
#  'three',
#  'day',
#  'taking',
#  'oxybutynin',
#  'day',
#  'sweat',
#  'free',
#  'negative',
#  'thing',
#  'say',
#  'drug',
#  'side',
#  'effect',
#  'gotten',
#  'fairly',
#  'dizzy',
#  'spaced',
#  'time',
#  'experience',
#  'dry',
#  'mouth',
#  'pretty',
#  'often',
#  'however',
#  'bad',
#  'comparison',
#  'acne',
#  'gotten',
#  'used',
#  'get',
#  'pimple',
#  'around',
#  'month',
#  'however',
#  'one',
#  'lasting',
#  'wks',
#  'varying',
#  'size',
#  'colour',
#  'constantly',
#  'group',
#  'acne',
#  'face',
#  'doe',
#  'anyone',
#  'remedy',
#  'tried',
#  'acne',
#  'mask',
#  'cleanser',
#  'tea',
#  'tree',
#  'oil']

# %%
vocabulary = {}

# %%
for i,r in enumerate(reviews, start=0):
        for j,w in enumerate(r , start=0):
            if w not in vocabulary:
                vocabulary[w] = [1,{i:[j]}]
            else:
                if i not in vocabulary[w][1]:
                    vocabulary[w][0] += 1
                    vocabulary[w][1][i] = [j]
                else:
                    if j not in vocabulary[w][1][i]:
                        vocabulary[w][1][i].append(j)

N = np.float64(data.shape[0])

# %%
for w in vocabulary.keys():
    pl = {}
    for i in vocabulary[w][1].keys():
        tf = (len(vocabulary[w][1][i])/len(reviews[i]))
        weight_i = (1 + np.log10(tf)) * np.log10(N/vocabulary[w][0])
        pl[i] = weight_i
    vocabulary[w].append(pl)
p = open('drugVocab.pickle',"wb")
pickle.dump(vocabulary,p)

# %%
tokenized = pd.Series(tokenized)

# %%
data['vector']=tokenized

# %%
data
# Out:
#        uniqueID                       drugName                     condition  \
# 0        163740                    Mirtazapine                    Depression
# 1        206473                     Mesalamine  Crohn's Disease, Maintenance
# 2        159672                        Bactrim       Urinary Tract Infection
# 3         39293                       Contrave                   Weight Loss
# 4         97768                Cyclafem 1 / 35                 Birth Control
# 5        208087                        Zyclara                     Keratosis
# 6        215892                         Copper                 Birth Control
# 7        169852                  Amitriptyline           Migraine Prevention
# 8         23295                      Methadone             Opiate Withdrawal
# 9         71428                         Levora                 Birth Control
# 10       196802                     Paroxetine                   Hot Flashes
# 11        31947                     Miconazole       Vaginal Yeast Infection
# 12         4907                         Belviq                   Weight Loss
# 13        66736                       Seroquel       Schizoaffective Disorde
# 14        97013                         Ambien                      Insomnia
# 15       213376                        Nuvigil                    Narcolepsy
# 16       151674                        Chantix             Smoking Cessation
# 17        33173          Microgestin Fe 1 / 20                          Acne
# 18        30401                       Klonopin               Bipolar Disorde
# 19       152490                  Ciprofloxacin       Urinary Tract Infection
# 20       231397                      Trazodone                      Insomnia
# 53765                                      "It works!!!"       9  13-Sep-09
#
#        usefulCount                                             vector
# 0               22  [tried, antidepressants, years, citalopram, fl...
# 1               17  [son, crohn, disease, done, well, asacol, comp...
# 2                3                       [quick, reduction, symptoms]
# 3               35  [contrave, combines, drugs, used, alcohol, smo...
# 4                4  [birth, control, one, cycle, after, reading, r...
# 5               13  [days, first, weeks, using, arms, face, put, v...
# 6                1  [copper, coil, months, really, excited, though...
# 7               32  [this, great, weeks, last, week, headaches, we...
# 8               21  [ive, methadone, ten, years, currently, trying...
# 9                3  [pill, almost, two, years, work, far, getting,...
# 10              17  [holy, hell, exactly, feel, taking, brisdelle,...
# 11               7  [honestly, day, one, day, treatment, yes, burn...
# 12              57  [this, waste, money, did, curb, appetite, make...
# 13              19                             [problems, watch, eat]
# 14              44  [ditto, rebound, sleepless, discontinued, done...
# 15              14  [doctor, prescribed, provigil, first, diagnose...
# 16              26  [smoked, years, took, one, week, think, possib...
# 17               1  [ginanvi, months, switched, pill, due, high, c...
# 18              24  [this, medication, helped, sleep, eventually, ...
# 19               9          [after, dose, ciprofloxacn, felt, better]
# 20              15  [could, give, would, absolutely, started, felt...
# 21              43  [happy, samples, provided, endocrinologist, th...
# 22              27  [after, days, kicked, every, noise, house, wou...
# 23              17                            [they, help, dry, eyes]
# 24              10  [this, drug, pretty, amazing, hyperhydrosis, p...
# 25              18  [this, medication, prescribed, bipolar, milder...
# 26              47          [klonopin, definitely, given, life, back]
# 27              38  [worked, quickly, well, learned, trial, trimmi...
# 28              19  [every, night, five, years, deeper, sleep, dre...
# 29               1  [year, old, female, diagnosed, bipolar, disord...
# ...            ...                                                ...
# 53736           79  [ativan, works, started, getting, panic, attac...
# 53737           19  [major, sleepiness, used, morning, evening, ti...
# 53738           34  [took, antibiotics, got, yeast, infection, wen...
# 53739           25  [ambien, wonderful, sleep, aid, for, people, t...
# 53740           44  [mild, barrett, esophagus, dexilant, month, du...
# 53741          140  [first, would, like, thank, posted, comments, ...
# 53742           16   [have, taking, years, milligrams, side, effects]
# 53743           15  [clarifoam, wonderful, product, rosacea, seb, ...
# 53744           53  [woman, cuban, puerto, rican, heritage, pounds...
# 53745           28  [clomipramine, years, basically, saved, life, ...
# 53746            6  [diarrhoea, days, minimal, sleep, constant, ab...
# 53747           12  [horrible, smoker, years, tried, chantix, drea...
# 53748            8                                  [glad, available]
# 53749           35  [after, years, opioid, heroin, addiction, trie...
# 53750           16  [worst, experience, pill, took, one, pill, hea...
# 53751            2  [took, chantix, little, month, made, psychotic...
# 53752           12  [after, first, month, taking, epclusa, undetec...
# 53753          123  [diagnosed, general, anxiety, disorder, would,...
# 53754            8  [help, craved, chocolate, time, not, worth, mo...
# 53755            5  [suffer, excessive, tiredness, lack, energy, c...
# 53756           36  [treatment, adhd, save, life, don, believe, hy...
# 53757           29  [this, time, taking, medicine, first, times, s...
# 53758           18  [this, medicine, kept, sleeping, whole, days, ...
# 53759           15  [microgestin, years, over, past, year, started...
# 53760           18  [started, taking, apri, months, ago, breats, g...
# 53761           43  [taken, tamoxifen, years, side, effects, sever...
# 53762           11  [taking, lexapro, escitaploprgram, since, febr...
# 53763            7  [married, years, old, kids, taking, pill, hass...
# 53764           20  [prescribed, nucynta, severe, neck, shoulder, ...
# 53765           46                                            [works]
#
# [53766 rows x 8 columns]

# %%
data.to_csv("fulldata.csv")

# %%
def topk(query):
    data = pd.read_csv('fulldata.csv', index_col='Unnamed: 0')
    p = open('drugVocab.pickle',"rb")
    vocabulary = pickle.load(p)

    q = query.replace("[^a-zA-Z]", " ").lower()
    q_vec = rm_stopword(q.split())
    q_vect = lem(q_vec.split())
    
    srtdpl = {}
    qw = {}
    for w in q_vect:
        if w in vocabulary.keys():
            if w not in srtdpl.keys():
                srtdpl[w] = sorted(vocabulary[w][2].items(), key=lambda x:x[1], reverse=True)[:10]
        if w not in qw:
            qw[w] = [1,(1/len(q_vect))]
        elif w in qw:
            qw[w][0] += 1
            qw[w][1] = (qw[w][0]/len(q_vect))
    if srtdpl == {}:
        return "No results found"
    
    topk = []
    N = data.shape[0]
    for i in range(N):
        count = 0
        sd = 0
        for w in q_vect:
            for (di,wt) in srtdpl[w]:
                if di == i: count += 1
        if count > 0 and count == len(q_vect):
            for w in q_vect:
                l = [x for x in srtdpl[w] if x[0] == i]
                sd += l[0][1] * qw[w][1]
            topk.append((i,sd))
        elif count > 0 and count < len(q_vec):
            for w in q_vect:
                l = srtdpl[w][9]
                sd += l[1] * qw[w][1]
            topk.append((i,sd))    
            
    out = [x for x in sorted(topk, key=lambda i:i[1], reverse=True)]        
    
 
 
    return out

# %%
query = "I have a headache"

# %%
res = topk(query)

# %%
  
print(res,"\n")
out = []
for (ind,s) in res:
    out.append( [data.loc[data.index[ind], 'drugName'], data.loc[data.index[ind], 'usefulCount'], data.loc[data.index[ind], 'condition'], data.loc[data.index[ind], 'rating'], data.loc[data.index[ind], 'review'], s*100])
#pd.set_option('display.max_columns', -1)  
#pd.set_option('display.expand_frame_repr', False)
#pd.set_option('max_colwidth', -1)
s = pd.Series(out) 
#show =  pd.DataFrame(s, columns=['Drug Name','Useful count','Condition','Rating(/10)','Review','Similarity%'])
print(s)
# Out:
# [(2690, 0.7694920812931749), (8903, 0.7694920812931749), (44137, 0.7694920812931749), (4591, 0.5756342210306166), (24579, 0.5756342210306166), (31922, 0.5756342210306166), (37816, 0.5756342210306166), (51167, 0.5756342210306166), (448, 0.43808988025709883), (10820, 0.43808988025709883)]
#
# 0    [Tizanidine, 10, Cluster Headaches, 5, "It works for headaches", 76.9492081293175]
# 1    [Lactulose, 12, nan, 10, "Headache, flatulence", 76.9492081293175]
# 2    [Ibuprofen, 4, Headache, 3, "didn't do much for my headaches", 76.9492081293175]
# 3    [Gabapentin, 51, ibromyalgia, 4, "Side effect for me is headaches.", 57.563422103061654]
# 4    [Isosorbide mononitrate, 9, Angina Pectoris Prophylaxis, 3, "Headaches, dizzy, nausea.", 57.563422103061654]
# 5    [Sumatriptan, 2, Migraine, 9, "It's the only drug that works for my headaches.", 57.563422103061654]
# 6    [Famciclovir, 18, Cold Sores, 6, "Causes major headaches for me.", 57.563422103061654]
# 7    [Acetaminophen / butalbital / caffeine, 15, Headache, 10, "It is the only thing that will stop my headache.", 57.563422103061654]
# 8    [Chateal, 1, Birth Control, 1, "This gave me headaches all the time. Stopped taking it and have been headache free !", 43.80898802570988]
# 9    [Nadolol, 25, Migraine Prevention, 10, "I've been taking this for 9 weeks - on 40mg daily. No headache - after having daily headaches for almost a year.", 43.80898802570988]
# dtype: object

# %%
pd.DataFrame(out, columns=['Drug Name','Useful count','Condition','Rating(/10)','Review','Similarity%'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     398                         if cls is not object \
#     399                                 and callable(cls.__dict__.get('__repr__')):
# --> 400                             return _repr_pprint(obj, self, cycle)
#     401
#     402             return _default_pprint(obj, self, cycle)
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     for idx,output_line in enumerate(output.splitlines()):
#     697         if idx:
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __repr__(self)
#      80         Yields Bytestring in Py2, Unicode String in py3.
#      81         """
# ---> 82         return str(self)
#      83
#      84
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __str__(self)
#      59
#      60         if compat.PY3:
# ---> 61             return self.__unicode__()
#      62         return self.__bytes__()
#      63
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __unicode__(self)
#     661             width = None
#     662         self.to_string(buf=buf, max_rows=max_rows, max_cols=max_cols,
# --> 663                        line_width=width, show_dimensions=show_dimensions)
#     664
#     665         return buf.getvalue()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, line_width, max_rows, max_cols, show_dimensions)
#    1966                                            max_cols=max_cols,
#    1967                                            show_dimensions=show_dimensions)
# -> 1968         formatter.to_string()
#    1969
#    1970         if buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     609         else:
#     610
# --> 611             strcols = self._to_str_columns()
#     612             if self.line_width is None:  # no need to wrap around just print
#     613                 # the whole frame
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _to_str_columns(self)
#     537                 str_columns = [[label] for label in self.header]
#     538             else:
# --> 539                 str_columns = self._get_formatted_column_labels(frame)
#     540
#     541             stringified = []
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_column_labels(self, frame)
#     790                             need_leadsp[x] else x]
#     791                            for i, (col, x) in enumerate(zip(columns,
# --> 792                                                             fmt_columns))]
#     793
#     794         if self.show_index_names and self.has_index_names:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in <listcomp>(.0)
#     789             str_columns = [[' ' + x if not self._get_formatter(i) and
#     790                             need_leadsp[x] else x]
# --> 791                            for i, (col, x) in enumerate(zip(columns,
#     792                                                             fmt_columns))]
#     793
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatter(self, i)
#     367         else:
#     368             if is_integer(i) and i not in self.columns:
# --> 369                 i = self.columns[i]
#     370             return self.formatters.get(i, None)
#     371
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    2067
#    2068         if is_scalar(key):
# -> 2069             return getitem(key)
#    2070
#    2071         if isinstance(key, slice):
#
# IndexError: index 6 is out of bounds for axis 0 with size 6
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     694
#     695             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 696                                 show_dimensions=show_dimensions, notebook=True)
#     697         else:
#     698             return None
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border, table_id)
#    2032                                            decimal=decimal, table_id=table_id)
#    2033         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 2034         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    2035
#    2036         if buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
#     749                                       table_id=self.table_id)
#     750         if hasattr(self.buf, 'write'):
# --> 751             html_renderer.write_result(self.buf)
#     752         elif isinstance(self.buf, compat.string_types):
#     753             with open(self.buf, 'w') as f:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\html.py in write_result(self, buf)
#     178         indent += self.indent_delta
#     179         indent = self._write_header(indent)
# --> 180         indent = self._write_body(indent)
#     181
#     182         self.write('</table>', indent)
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\html.py in _write_body(self, indent)
#     341                 self._write_hierarchical_rows(fmt_values, indent)
#     342             else:
# --> 343                 self._write_regular_rows(fmt_values, indent)
#     344         else:
#     345             for i in range(min(len(self.frame), self.max_rows)):
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\html.py in _write_regular_rows(self, fmt_values, indent)
#     375             row = []
#     376             row.append(index_values[i])
# --> 377             row.extend(fmt_values[j][i] for j in range(ncols))
#     378
#     379             if truncate_h:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\html.py in <genexpr>(.0)
#     375             row = []
#     376             row.append(index_values[i])
# --> 377             row.extend(fmt_values[j][i] for j in range(ncols))
#     378
#     379             if truncate_h:
#
# KeyError: 0

# %%
out =  pd.DataFrame(out, columns=['Drug Name','Useful count','Condition','Rating(/10)','Review','Similarity%'])

# %%
out
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     398                         if cls is not object \
#     399                                 and callable(cls.__dict__.get('__repr__')):
# --> 400                             return _repr_pprint(obj, self, cycle)
#     401
#     402             return _default_pprint(obj, self, cycle)
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     for idx,output_line in enumerate(output.splitlines()):
#     697         if idx:
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __repr__(self)
#      80         Yields Bytestring in Py2, Unicode String in py3.
#      81         """
# ---> 82         return str(self)
#      83
#      84
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __str__(self)
#      59
#      60         if compat.PY3:
# ---> 61             return self.__unicode__()
#      62         return self.__bytes__()
#      63
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __unicode__(self)
#     661             width = None
#     662         self.to_string(buf=buf, max_rows=max_rows, max_cols=max_cols,
# --> 663                        line_width=width, show_dimensions=show_dimensions)
#     664
#     665         return buf.getvalue()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, line_width, max_rows, max_cols, show_dimensions)
#    1966                                            max_cols=max_cols,
#    1967                                            show_dimensions=show_dimensions)
# -> 1968         formatter.to_string()
#    1969
#    1970         if buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     609         else:
#     610
# --> 611             strcols = self._to_str_columns()
#     612             if self.line_width is None:  # no need to wrap around just print
#     613                 # the whole frame
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _to_str_columns(self)
#     537                 str_columns = [[label] for label in self.header]
#     538             else:
# --> 539                 str_columns = self._get_formatted_column_labels(frame)
#     540
#     541             stringified = []
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_column_labels(self, frame)
#     790                             need_leadsp[x] else x]
#     791                            for i, (col, x) in enumerate(zip(columns,
# --> 792                                                             fmt_columns))]
#     793
#     794         if self.show_index_names and self.has_index_names:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in <listcomp>(.0)
#     789             str_columns = [[' ' + x if not self._get_formatter(i) and
#     790                             need_leadsp[x] else x]
# --> 791                            for i, (col, x) in enumerate(zip(columns,
#     792                                                             fmt_columns))]
#     793
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatter(self, i)
#     367         else:
#     368             if is_integer(i) and i not in self.columns:
# --> 369                 i = self.columns[i]
#     370             return self.formatters.get(i, None)
#     371
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    2067
#    2068         if is_scalar(key):
# -> 2069             return getitem(key)
#    2070
#    2071         if isinstance(key, slice):
#
# IndexError: index 6 is out of bounds for axis 0 with size 6
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     694
#     695             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 696                                 show_dimensions=show_dimensions, notebook=True)
#     697         else:
#     698             return None
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border, table_id)
#    2032                                            decimal=decimal, table_id=table_id)
#    2033         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 2034         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    2035
#    2036         if buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
#     749                                       table_id=self.table_id)
#     750         if hasattr(self.buf, 'write'):
# --> 751             html_renderer.write_result(self.buf)
#     752         elif isinstance(self.buf, compat.string_types):
#     753             with open(self.buf, 'w') as f:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\html.py in write_result(self, buf)
#     178         indent += self.indent_delta
#     179         indent = self._write_header(indent)
# --> 180         indent = self._write_body(indent)
#     181
#     182         self.write('</table>', indent)
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\html.py in _write_body(self, indent)
#     341                 self._write_hierarchical_rows(fmt_values, indent)
#     342             else:
# --> 343                 self._write_regular_rows(fmt_values, indent)
#     344         else:
#     345             for i in range(min(len(self.frame), self.max_rows)):
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\html.py in _write_regular_rows(self, fmt_values, indent)
#     375             row = []
#     376             row.append(index_values[i])
# --> 377             row.extend(fmt_values[j][i] for j in range(ncols))
#     378
#     379             if truncate_h:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\html.py in <genexpr>(.0)
#     375             row = []
#     376             row.append(index_values[i])
# --> 377             row.extend(fmt_values[j][i] for j in range(ncols))
#     378
#     379             if truncate_h:
#
# KeyError: 0
